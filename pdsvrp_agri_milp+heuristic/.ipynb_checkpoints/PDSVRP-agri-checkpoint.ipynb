# %%
from gurobipy import *
import numpy as np
import pandas as pd
from scipy.spatial import distance
from itertools import chain, combinations
import matplotlib.pyplot as plt
import os, sys
import readData as dt
import math

# %%
dt = dt.Data()
dt.get_data("input/test1/P-n8-k2.vrp")

# %%
dt.distance_matrix
# Out:
# [[0, 13.89, 19.24, 32.56, 22.02, 23.09, 12.04, 22.02, 0],
#  [13.89, 0, 15.0, 19.21, 11.66, 24.21, 12.08, 18.6, 13.89],
#  [19.24, 15.0, 0, 21.21, 26.17, 10.44, 7.28, 3.61, 19.24],
#  [32.56, 19.21, 21.21, 0, 21.1, 31.0, 25.08, 23.0, 32.56],
#  [22.02, 11.66, 26.17, 21.1, 0, 35.81, 23.71, 29.7, 22.02],
#  [23.09, 24.21, 10.44, 31.0, 35.81, 0, 12.81, 8.0, 23.09],
#  [12.04, 12.08, 7.28, 25.08, 23.71, 12.81, 0, 10.0, 12.04],
#  [22.02, 18.6, 3.61, 23.0, 29.7, 8.0, 10.0, 0, 22.02]]

# %%
dt.drone_time_matrix
# Out:
# [[0.0, 6.95, 9.62, 16.28, 11.01, 11.54, 6.02, 11.01, 0],
#  [6.95, 0.0, 7.5, 9.61, 5.83, 12.11, 6.04, 9.3, 13.89],
#  [9.62, 7.5, 0.0, 10.61, 13.09, 5.22, 3.64, 1.8, 19.24],
#  [16.28, 9.61, 10.61, 0.0, 10.55, 15.5, 12.54, 11.5, 32.56],
#  [11.01, 5.83, 13.09, 10.55, 0.0, 17.91, 11.86, 14.85, 22.02],
#  [11.54, 12.11, 5.22, 15.5, 17.91, 0.0, 6.41, 4.0, 23.09],
#  [6.02, 6.04, 3.64, 12.54, 11.86, 6.41, 0.0, 5.0, 12.04],
#  [11.01, 9.3, 1.8, 11.5, 14.85, 4.0, 5.0, 0.0, 22.02]]

# %%
# #Set
# C = [] #set of customers
# C_0 = [] #set of customers and depot
# C_plus = [] #set of customers and copy of depot
# N = [] #set of all nodes
# K = [] #set of trucks
# D = [] #set of small drones
# Q = [] #set of customers' demand
# CL = [] #set of low-perishability products customers
# CH = [] #set of high-perishability products customers
# #

# T = None #completion time
# QT = None #truck capacity

# QSD = None #small drone capacity


# #

# %%
# dt.num_of_truck = 2
dt.num_of_drone 
dt.num_of_truck
# Out:
# 2

# %%
n = dt.num_of_customer - 1

C = [i for i in range(1, n+1)]
C_0 = [i for i in range(0, n+1)]
C_plus = [i for i in range(1, n + 2)]
N = [i for i in range(0, n+2)]
K = [i for i in range(dt.num_of_truck)]
D = [i for i in range(dt.num_of_drone)]
Q = dt.demand_matrix

# CL = [i for i in range(5,10)]
# CH = [i for i in range(1,5)]
QT = dt.QT
QD = dt.QD
# TL = 50
# TH = 100
sp = dt.sp
cost_t = dt.truck_time_matrix
cost_td = dt.drone_time_matrix
M = GRB.MAXINT
theta = dt.theta
phi = dt.phi
Q
CD = [i for i in C if QD >= dt.Q[i]]
CD
# Out:
# [3, 5, 7]

# %%
 # initializing drone time matrix
# for i in range(dt.num_of_customer):
#     for j in range(dt.num_of_customer):
#         cost_td[i][j] = cost_td[i][j] / sp
# for i in range(dt.num_of_customer):
#     for j in range(dt.num_of_customer):
#            cost_td[i][j] = round(cost_td[i][j], 2)
cost_td
# Out:
# [[0.0, 6.95, 9.62, 16.28, 11.01, 11.54, 6.02, 11.01, 0],
#  [6.95, 0.0, 7.5, 9.61, 5.83, 12.11, 6.04, 9.3, 13.89],
#  [9.62, 7.5, 0.0, 10.61, 13.09, 5.22, 3.64, 1.8, 19.24],
#  [16.28, 9.61, 10.61, 0.0, 10.55, 15.5, 12.54, 11.5, 32.56],
#  [11.01, 5.83, 13.09, 10.55, 0.0, 17.91, 11.86, 14.85, 22.02],
#  [11.54, 12.11, 5.22, 15.5, 17.91, 0.0, 6.41, 4.0, 23.09],
#  [6.02, 6.04, 3.64, 12.54, 11.86, 6.41, 0.0, 5.0, 12.04],
#  [11.01, 9.3, 1.8, 11.5, 14.85, 4.0, 5.0, 0.0, 22.02]]

# %%
#variables
x = {}


y = {}
yd = {}

t = {}
td = {}

u = {}
w1 = {}
w2 = {}
w3 = {}
w4 = {}
w5 = {}
w6 = {}

# %%
# model = Model('VRPTD')
#DECISION VARIABLES
def addConstr():
    for k in K:
        for i in N:
            w1[k,i] = model.addVar(lb=-GRB.INFINITY, ub=GRB.INFINITY, vtype = GRB.CONTINUOUS,name = "w1%d,%d" %(k,i))

    for d in D:
        for i in N:
            w2[d,i] = model.addVar(lb=-GRB.INFINITY, ub=GRB.INFINITY, vtype = GRB.CONTINUOUS,name = "w2%d,%d" %(d,i))


    for k in K:
        for i in N:
            w3[k,i] = model.addVar(0,1,name = "w3%d,%d" %(k,i))

    for d in D:
        for i in N:
            w4[d,i] = model.addVar( lb=-GRB.INFINITY, ub=GRB.INFINITY, vtype = GRB.CONTINUOUS,name = "w4%d,%d" %(d,i))
    for k in K:
        for i in N:
            w5[k,i] = model.addVar(lb=-GRB.INFINITY, ub=GRB.INFINITY, vtype = GRB.CONTINUOUS,name = "w5%d,%d" %(k,i))

    for d in D:
        for i in N:
            w6[d,i] = model.addVar(lb=-GRB.INFINITY, ub=GRB.INFINITY, vtype = GRB.CONTINUOUS,name = "w6%d,%d" %(d,i))


    for k in K:
        for i in N:
            y[k,i] = model.addVar(0, 1, vtype = GRB.BINARY,name = "y%d,%d" %(k,i))
            for j in N:
                x[k,i,j] = model.addVar(0, 1, vtype = GRB.BINARY,name = "x%d,%d,%d" %(k,i,j))

    # for cd in CD:
    #     for i in N:
    #         yd[d,i] = model.addVar(0, 1, vtype = GRB.BINARY,name = "ycd%d,%d" %(cd,i))
    #         for j in N:
    #             xcd[cd,i,j] = model.addVar(0, 1, vtype = GRB.BINARY,name = "xcd%d,%d,%d" %(cd,i,j))

    for d in D:
        for i in C:
            yd[d,i] = model.addVar(0, 1, vtype = GRB.BINARY,name = "yd%d,%d" %(d,i))
    #         xd[d,i] = model.addVar(0, 1, vtype = GRB.BINARY,name = "xd%d,%d" %(d,i))

    for k in K:
        for i in N:
            t[k,i] = model.addVar(0, GRB.INFINITY, 1.0, GRB.CONTINUOUS, name = "t%d,%d" %(k,i))


    for d in D:
        for i in N:
            td[d,i] = model.addVar(0, GRB.INFINITY, 1.0, GRB.CONTINUOUS, name = "td%d,%d" %(d,i))
    for k in K:
        for i in N:
            u[k,i] = model.addVar(0, GRB.INFINITY, vtype = GRB.CONTINUOUS, name = "u%d" %i)






    QDV = model.addVar(0, GRB.INFINITY, 1.0, GRB.CONTINUOUS, "QDV")    
    alpha = model.addVar(0, GRB.INFINITY, 1.0, GRB.CONTINUOUS, "traveltime")

    expr0 = LinExpr(0)
    expr1 = LinExpr(0)
    expr0.addTerms(1-theta, QDV)
    expr1.addTerms(theta, alpha)
    model.setObjective(expr0 + expr1, GRB.MINIMIZE)



    #objective
    tmp_expr0 = LinExpr(0)
    tmp_expr1 = LinExpr(0)
    tmp_expr2 = LinExpr(0)
    for k in K:
        tmp_expr0.addTerms(1.0, t[k, n+1])
    for d in D:
        for i in C:
            tmp_expr1.addTerms(1.0, td[d, i])
    model.addConstr(alpha >= tmp_expr0 + tmp_expr1 )

    # model.update()
    # print(tmp_expr0)
    # print(tmp_expr1)
    # print(tmp_expr2)




    #TDV
    QDV_truck = QuadExpr(0)
    QDV_drone = QuadExpr(0)
    # QDVH_truck = QuadExpr(0)
    # QDVH_drone = QuadExpr(0)
    for i in C:
        for k in K:

            QDV_truck.addTerms(Q[i]*phi, t[k,i], y[k,i])
            model.update()

        for d in D:

                QDV_drone.addTerms(Q[i]*phi, td[d,i], yd[d,i])
    # for i in CH:
    #     for k in K:

    #         QDVH_truck.addTerms(Q[i]*phi_high, t[k,i], y[k,i])
    #         model.update()

    #     for d in D:
    #         if i in CD:
    #             QDVH_drone.addTerms(Q[i]*phi_high, td[d,i], yd[d,i])

    #e^-phi_high*t

    # for i in CH:
    #     for k in K:
    #         model.addConstr(w1[k,i] == -phi_high*t[k,i])

    # for i in CH:
    #     for d in D:
    #         if i in CD:
    #             model.addConstr(w2[d,i] == -phi_high* td[d,i])
    # for i in CH:
    #     for k in K:
    #         model.addGenConstrExp(w1[k,i], w3[k,i],"FuncPieces=-1 FuncPieceError=0.001")

    # for i in CH:
    #     for d in D:
    #         if i in CD:
    #             model.addGenConstrExp(w2[d,i],w4[d,i], "FuncPieces=-1 FuncPieceError=0.001")

    # for i in CH:
    #     for k in K:
    #         model.addConstr(w5[k,i] == 1 - w3[k,i])

    # for i in CH:
    #     for d in D:
    #         model.addConstr(w6[d,i] == 1 - w4[d,i])

    # for i in CH:
    #     for k in K:
    #         QDVH_truck.addTerms(Q[i], w5[k,i] , y[k,i])
    #     for d in D:
    #         if i in CD:
    #             QDVH_drone.addTerms(Q[i], w6[d,i], yd[d,i])    
    # for i in CH:
    #     for k in K:
    #         tmp_truck = -phi_high*t[k,i]
    #         QDVH_truck.addTerms(Q[i], 1 - math.exp(tmp_truck), y[k,i])
    #     for d in D:
    #         if i in CD:
    #             tmp_drone = -phi_high*td[d,i]
    #             QDVH_drone.addTerms(Q[i], 1 - math.exp(tmp_drone), yd[d,i])  

    model.addConstr(QDV >= QDV_truck + QDV_drone  )


    tmp_expr0 = LinExpr(0)
    tmp_expr1 = LinExpr(0)

    for k in K:
         for i in C_0:
                for j in C_plus:
                    tmp_expr0.addTerms(cost_t[i][j], x[k, i,j])

    for d in D:
        for i in C:
            tmp_expr1.addTerms(cost_td[0][i], yd[d, i])
    model.addConstr(alpha >= tmp_expr0 + tmp_expr1)

    #2
    for i in C:
        tmp_expr0 = LinExpr(0)
        tmp_expr1 = LinExpr(0)

        for k in K:
            tmp_expr0.addTerms(1.0, y[k,i])

        for d in D:
            tmp_expr1.addTerms(1.0, yd[d,i])
    #     model.update()
    #     print(tmp_expr0)
        model.addConstr(tmp_expr0 + tmp_expr1  == 1)
    #3
    for k in K:
        tmp_expr = LinExpr(0)
        for i in C_plus:
            tmp_expr.addTerms(1.0, x[k,0,i])
        model.addConstr(tmp_expr == 1)
        tmp_expr.clear()

    #4
    for k in K:
        tmp_expr = LinExpr(0)
        for i in C_0:
            tmp_expr.addTerms(1.0, x[k,i,n+1])
        model.addConstr(tmp_expr == 1)
        tmp_expr.clear()

    #5
    for i in C:
        for k in K:
            tmp_expr0 = LinExpr(0)
            tmp_expr1 = LinExpr(0)
            for j in C_0:
                tmp_expr0.addTerms(1.0, x[k,j,i])
            for j in C_plus:
                tmp_expr1.addTerms(1.0, x[k,i,j])
            model.addConstr(tmp_expr1 == tmp_expr0) 
            model.addConstr(y[k,i] == tmp_expr0) 
            model.addConstr(y[k,i] == tmp_expr1) 
            tmp_expr0.clear()
            tmp_expr1.clear()


    #9
    # for d in D:
    #     tmp_expr = LinExpr(0)
    #     for i in C:
    # # TDL = LinExpr(0)

    # # for k in K:
    # #     for i in CL:
    # #         tmp_expr0.addTerms(,y[k,i])
    #         tmp_expr.addTerms(1.0, yd[d,i])
    #     model.addConstr(tmp_expr <= 1)

    #10

    for k in K:
        tmp_expr = LinExpr(0)
        for i in C:
            tmp_expr.addTerms(Q[i], y[k,i])
        model.addConstr(tmp_expr <= QT)
        tmp_expr.clear()

    # #11
    # for cd in CD:
    #     tmp_expr = LinExpr(0)
    #     for i in C:
    #         tmp_expr.addTerms(D[i], ycd[cd,i])
    #     model.addConstr(tmp_expr <= QCD)
    #     tmp_expr.clear()

    #12
    for d in D:
        tmp_expr = LinExpr(0)
        for i in C:
            tmp_expr.addTerms(Q[i], yd[d,i])
        model.addConstr(tmp_expr <= QD)
        tmp_expr.clear()
    #13 arrival time

    for i in C_0:
        for j in C_plus:
            for k in K:
                model.addConstr(t[k,j] >= t[k,i] + cost_t[i][j] - M*(1-x[k,i,j]))


    #15

    for i in C:
        for d in D:
            model.addConstr(td[d,i] >= cost_td[0][i]    - M*(1 - yd[d,i]) )

    # for i in C:
    #         for d in d:
    #             model.addConstr(td[d,i] == yd[d,i]*cost_td[0][i])           
    # 16

    # for i in CL:
    #     tmp_expr0 = QuadExpr(0)
    #     tmp_expr1 = QuadExpr(0)


    #     for k in K:
    #         tmp_expr0.addTerms(1.0, t[k,i], y[k,i])


    #     for d in D:
    #         tmp_expr1.addTerms(1.0, td[d,i], yd[d,i])
    #         print(tmp_expr1)

    #     model.addConstr(tmp_expr0 + tmp_expr1 <= TL)

    # #17
    # for i in CH:
    #     tmp_expr0 = QuadExpr(0)
    #     tmp_expr1 = QuadExpr(0)

    #     for k in K:
    #         tmp_expr0.addTerms(1.0, t[k,i], y[k,i])
    #         model.update()
    #         print (tmp_expr0)

    #     for d in D:
    #         tmp_expr1.addTerms(1.0, td[d,i], yd[d,i])

    #     model.addConstr(tmp_expr0 + tmp_expr1  <= TH)

    #18
    for i in N:
        for j in N:
            for k in K:
                tmp0 = u[k,i] - u[k,j] + QT*x[k,i,j]
                tmp1 = QT - Q[j]

                model.addConstr(tmp0 <= tmp1)
    #19

    for i in N:
        for k in K:
            model.addConstr(u[k,i] >= Q[i])
            model.addConstr(u[k,i] <= QT)



    #domain constraints
    # for k in K:
    #     for j in C:
    #         model.addConstr(t[k,j] >= 0)
    # for cd in CD:
    #     for j in C:
    #         model.addConstr(tcd[cd,j] >= 0)
    # for d in d:
    #     for j in C:
    #         model.addConstr(td[d,j] >= 0)

# %%
dir_path = os.path.dirname(os.path.abspath("__file__"))
tt = np.arange(0.0, 1.01, 0.01)
obj = []
qdv = []
for i in range(len(tt)):
    model = Model('VRPTD')
    addConstr()
    theta = tt[i]
    model.optimize()
   
    for v in model.getVars():
        print(v.VarName)
        if v.VarName == 'QDV':
            qdv.append(v.X)

        if v.VarName == 'traveltime':
            obj.append(v.X)
         
#         print(f"{v.VarName} = {v.X}")
#         print(v.QDV.X)
    
df = pd.DataFrame() 
df['obj'] = obj
df['qdv'] = qdv

df.to_csv(dir_path + '/result/new', index = False, header=False)
# Out:
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 391 rows, 315 columns and 1508 nonzeros
# Model fingerprint: 0x5e8d7307
# Model has 1 quadratic constraint
# Variable types: 128 continuous, 187 integer (187 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+09]
#   QMatrix range    [1e+00, 3e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 143 rows and 159 columns
# Presolve time: 0.00s
# Presolved: 248 rows, 156 columns, 1667 nonzeros
# Variable types: 30 continuous, 126 integer (126 binary)
# Found heuristic solution: objective 168.7400000
#
# Root relaxation: objective 7.016000e+01, 97 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   70.16000    0   18  168.74000   70.16000  58.4%     -    0s
# H    0     0                     138.2100000   70.16000  49.2%     -    0s
#      0     0   82.51028    0   27  138.21000   82.51028  40.3%     -    0s
#      0     0   82.53000    0   26  138.21000   82.53000  40.3%     -    0s
#      0     0   86.92400    0   24  138.21000   86.92400  37.1%     -    0s
#      0     0   87.73025    0   24  138.21000   87.73025  36.5%     -    0s
# H    0     0                     137.2800000   89.71744  34.6%     -    0s
# H    0     0                     131.5200000   89.71744  31.8%     -    0s
#      0     0   89.86800    0   21  131.52000   89.86800  31.7%     -    0s
#      0     0   90.30065    0   21  131.52000   90.30065  31.3%     -    0s
#      0     0   91.92948    0   21  131.52000   91.92948  30.1%     -    0s
#      0     0   93.31770    0   21  131.52000   93.31770  29.0%     -    0s
#      0     2   93.31770    0   21  131.52000   93.31770  29.0%     -    0s
# H   74    36                     131.5199995   93.31770  29.0%  11.2    0s
# H  193    48                     131.5199990   93.31770  29.0%  10.2    0s
# *  363   104              13     192.2950315   97.93308  49.1%  20.1    0s
# *  368   104               9     173.8213715  100.34350  42.3%  20.1    0s
# *  483    44               9     161.0374768  117.08036  27.3%  18.8    0s
#
# Cutting planes:
#   Learned: 3
#   Cover: 2
#   Implied bound: 46
#   Clique: 3
#   MIR: 5
#   RLT: 3
#   Relax-and-lift: 33
#
# Explored 543 nodes (9731 simplex iterations) in 0.17 seconds (0.14 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 161.037 173.821 192.295 ... 360.861
# No other solutions better than 161.037
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.610374767386e+02, best bound 1.610374767386e+02, gap 0.0000%
# w10,0
# w10,1
# w10,2
# w10,3
# w10,4
# w10,5
# w10,6
# w10,7
# w10,8
# w11,0
# w11,1
# w11,2
# w11,3
# w11,4
# w11,5
# w11,6
# w11,7
# w11,8
# w20,0
# w20,1
# w20,2
# w20,3
# w20,4
# w20,5
# w20,6
# w20,7
# w20,8
# w30,0
# w30,1
# w30,2
# w30,3
# w30,4
# w30,5
# w30,6
# w30,7
# w30,8
# w31,0
# w31,1
# w31,2
# w31,3
# w31,4
# w31,5
# w31,6
# w31,7
# w31,8
# w40,0
# w40,1
# w40,2
# w40,3
# w40,4
# w40,5
# w40,6
# w40,7
# w40,8
# w50,0
# w50,1
# w50,2
# w50,3
# w50,4
# w50,5
# w50,6
# w50,7
# w50,8
# w51,0
# w51,1
# w51,2
# w51,3
# w51,4
# w51,5
# w51,6
# w51,7
# w51,8
# w60,0
# w60,1
# w60,2
# w60,3
# w60,4
# w60,5
# w60,6
# w60,7
# w60,8
# y0,0
# x0,0,0
# x0,0,1
# x0,0,2
# x0,0,3
# x0,0,4
# x0,0,5
# x0,0,6
# x0,0,7
# x0,0,8
# y0,1
# x0,1,0
# x0,1,1
# x0,1,2
# x0,1,3
# x0,1,4
# x0,1,5
# x0,1,6
# x0,1,7
# x0,1,8
# y0,2
# x0,2,0
# x0,2,1
# x0,2,2
# x0,2,3
# x0,2,4
# x0,2,5
# x0,2,6
# x0,2,7
# x0,2,8
# y0,3
# x0,3,0
# x0,3,1
# x0,3,2
# x0,3,3
# x0,3,4
# x0,3,5
# x0,3,6
# x0,3,7
# x0,3,8
# y0,4
# x0,4,0
# x0,4,1
# x0,4,2
# x0,4,3
# x0,4,4
# x0,4,5
# x0,4,6
# x0,4,7
# x0,4,8
# y0,5
# x0,5,0
# x0,5,1
# x0,5,2
# x0,5,3
# x0,5,4
# x0,5,5
# x0,5,6
# x0,5,7
# x0,5,8
# y0,6
# x0,6,0
# x0,6,1
# x0,6,2
# x0,6,3
# x0,6,4
# x0,6,5
# x0,6,6
# x0,6,7
# x0,6,8
# y0,7
# x0,7,0
# x0,7,1
# x0,7,2
# x0,7,3
# x0,7,4
# x0,7,5
# x0,7,6
# x0,7,7
# x0,7,8
# y0,8
# x0,8,0
# x0,8,1
# x0,8,2
# x0,8,3
# x0,8,4
# x0,8,5
# x0,8,6
# x0,8,7
# x0,8,8
# y1,0
# x1,0,0
# x1,0,1
# x1,0,2
# x1,0,3
# x1,0,4
# x1,0,5
# x1,0,6
# x1,0,7
# x1,0,8
# y1,1
# x1,1,0
# x1,1,1
# x1,1,2
# x1,1,3
# x1,1,4
# x1,1,5
# x1,1,6
# x1,1,7
# x1,1,8
# y1,2
# x1,2,0
# x1,2,1
# x1,2,2
# x1,2,3
# x1,2,4
# x1,2,5
# x1,2,6
# x1,2,7
# x1,2,8
# y1,3
# x1,3,0
# x1,3,1
# x1,3,2
# x1,3,3
# x1,3,4
# x1,3,5
# x1,3,6
# x1,3,7
# x1,3,8
# y1,4
# x1,4,0
# x1,4,1
# x1,4,2
# x1,4,3
# x1,4,4
# x1,4,5
# x1,4,6
# x1,4,7
# x1,4,8
# y1,5
# x1,5,0
# x1,5,1
# x1,5,2
# x1,5,3
# x1,5,4
# x1,5,5
# x1,5,6
# x1,5,7
# x1,5,8
# y1,6
# x1,6,0
# x1,6,1
# x1,6,2
# x1,6,3
# x1,6,4
# x1,6,5
# x1,6,6
# x1,6,7
# x1,6,8
# y1,7
# x1,7,0
# x1,7,1
# x1,7,2
# x1,7,3
# x1,7,4
# x1,7,5
# x1,7,6
# x1,7,7
# x1,7,8
# y1,8
# x1,8,0
# x1,8,1
# x1,8,2
# x1,8,3
# x1,8,4
# x1,8,5
# x1,8,6
# x1,8,7
# x1,8,8
# yd0,1
# yd0,2
# yd0,3
# yd0,4
# yd0,5
# yd0,6
# yd0,7
# t0,0
# t0,1
# t0,2
# t0,3
# t0,4
# t0,5
# t0,6
# t0,7
# t0,8
# t1,0
# t1,1
# t1,2
# t1,3
# t1,4
# t1,5
# t1,6
# t1,7
# t1,8
# td0,0
# td0,1
# td0,2
# td0,3
# td0,4
# td0,5
# td0,6
# td0,7
# td0,8
# u0
# u1
# u2
# u3
# u4
# u5
# u6
# u7
# u8
# u0
# u1
# u2
# u3
# u4
# u5
# u6
# u7
# u8
# QDV
# 161.37098664549973
# traveltime
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 391 rows, 315 columns and 1508 nonzeros
# Model fingerprint: 0x16106825
# Model has 1 quadratic constraint
# Variable types: 128 continuous, 187 integer (187 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+09]
#   QMatrix range    [1e+00, 3e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [2e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 139 rows and 155 columns
# Presolve time: 0.01s
# Presolved: 286 rows, 211 columns, 1755 nonzeros
# Presolved model has 34 SOS constraint(s)
# Variable types: 67 continuous, 144 integer (144 binary)
# Found heuristic solution: objective 457.6209804
#
# Root relaxation: objective 1.403200e+00, 106 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.40320    0   45  457.62098    1.40320   100%     -    0s
# H    0     0                     393.3693018    1.40320   100%     -    0s
# H    0     0                     375.8481970    1.40320   100%     -    0s
# H    0     0                     375.8481932    1.65060   100%     -    0s
#      0     0    1.70240    0   45  375.84819    1.70240   100%     -    0s
#      0     0   26.93024    0   45  375.84819   26.93024  92.8%     -    0s
# H    0     0                     375.8481441   26.93024  92.8%     -    0s
#      0     0   32.23011    0   45  375.84814   32.23011  91.4%     -    0s
#      0     0   32.23391    0   45  375.84814   32.23391  91.4%     -    0s
# H    0     0                     339.9072018   32.23391  90.5%     -    0s
#      0     0   32.33140    0   45  339.90720   32.33140  90.5%     -    0s
#      0     0   32.33140    0   45  339.90720   32.33140  90.5%     -    0s
#      0     2   32.33140    0   45  339.90720   32.33140  90.5%     -    0s
# H   19    26                     308.0858959   55.17965  82.1%  51.6    0s
# H   20    26                     264.0792727   55.17965  79.1%  50.7    0s
# *   90   100              12     252.8990400   59.94158  76.3%  30.7    0s
# *  111   116              13     248.6468393   59.94158  75.9%  27.1    0s
# *  130   128              17     223.5032798   59.94158  73.2%  24.9    0s
# *  233   127              10     217.3014400   67.01913  69.2%  21.2    0s
# *  251   120              11     203.6020118   69.60009  65.8%  20.7    0s
# *  278   120              10     198.7798751   69.60009  65.0%  19.6    0s
# *  306   107               8     165.4831798   96.71693  41.6%  19.2    0s
#
# Cutting planes:
#   Learned: 3
#   Cover: 2
#   Implied bound: 43
#   Clique: 3
#   MIR: 2
#   RLT: 2
#   Relax-and-lift: 34
#
# Explored 484 nodes (8086 simplex iterations) in 0.17 seconds (0.13 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 165.483 198.78 203.602 ... 375.848
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.654831798440e+02, best bound 1.654831798440e+02, gap 0.0000%
# w10,0
# w10,1
# w10,2
# w10,3
# w10,4
# w10,5
# w10,6
# w10,7
# w10,8
# w11,0
# w11,1
# w11,2
# w11,3
# w11,4
# w11,5
# w11,6
# w11,7
# w11,8
# w20,0
# w20,1
# w20,2
# w20,3
# w20,4
# w20,5
# w20,6
# w20,7
# w20,8
# w30,0
# w30,1
# w30,2
# w30,3
# w30,4
# w30,5
# w30,6
# w30,7
# w30,8
# w31,0
# w31,1
# w31,2
# w31,3
# w31,4
# w31,5
# w31,6
# w31,7
# w31,8
# w40,0
# w40,1
# w40,2
# w40,3
# w40,4
# w40,5
# w40,6
# w40,7
# w40,8
# w50,0
# w50,1
# w50,2
# w50,3
# w50,4
# w50,5
# w50,6
# w50,7
# w50,8
# w51,0
# w51,1
# w51,2
# w51,3
# w51,4
# w51,5
# w51,6
# w51,7
# w51,8
# w60,0
# w60,1
# w60,2
# w60,3
# w60,4
# w60,5
# w60,6
# w60,7
# w60,8
# y0,0
# x0,0,0
# x0,0,1
# x0,0,2
# x0,0,3
# x0,0,4
# x0,0,5
# x0,0,6
# x0,0,7
# x0,0,8
# y0,1
# x0,1,0
# x0,1,1
# x0,1,2
# x0,1,3
# x0,1,4
# x0,1,5
# x0,1,6
# x0,1,7
# x0,1,8
# y0,2
# x0,2,0
# x0,2,1
# x0,2,2
# x0,2,3
# x0,2,4
# x0,2,5
# x0,2,6
# x0,2,7
# x0,2,8
# y0,3
# x0,3,0
# x0,3,1
# x0,3,2
# x0,3,3
# x0,3,4
# x0,3,5
# x0,3,6
# x0,3,7
# x0,3,8
# y0,4
# x0,4,0
# x0,4,1
# x0,4,2
# x0,4,3
# x0,4,4
# x0,4,5
# x0,4,6
# x0,4,7
# x0,4,8
# y0,5
# x0,5,0
# x0,5,1
# x0,5,2
# x0,5,3
# x0,5,4
# x0,5,5
# x0,5,6
# x0,5,7
# x0,5,8
# y0,6
# x0,6,0
# x0,6,1
# x0,6,2
# x0,6,3
# x0,6,4
# x0,6,5
# x0,6,6
# x0,6,7
# x0,6,8
# y0,7
# x0,7,0
# x0,7,1
# x0,7,2
# x0,7,3
# x0,7,4
# x0,7,5
# x0,7,6
# x0,7,7
# x0,7,8
# y0,8
# x0,8,0
# x0,8,1
# x0,8,2
# x0,8,3
# x0,8,4
# x0,8,5
# x0,8,6
# x0,8,7
# x0,8,8
# y1,0
# x1,0,0
# x1,0,1
# x1,0,2
# x1,0,3
# x1,0,4
# x1,0,5
# x1,0,6
# x1,0,7
# x1,0,8
# y1,1
# x1,1,0
# x1,1,1
# x1,1,2
# x1,1,3
# x1,1,4
# x1,1,5
# x1,1,6
# x1,1,7
# x1,1,8
# y1,2
# x1,2,0
# x1,2,1
# x1,2,2
# x1,2,3
# x1,2,4
# x1,2,5
# x1,2,6
# x1,2,7
# x1,2,8
# y1,3
# x1,3,0
# x1,3,1
# x1,3,2
# x1,3,3
# x1,3,4
# x1,3,5
# x1,3,6
# x1,3,7
# x1,3,8
# y1,4
# x1,4,0
# x1,4,1
# x1,4,2
# x1,4,3
# x1,4,4
# x1,4,5
# x1,4,6
# x1,4,7
# x1,4,8
# y1,5
# x1,5,0
# x1,5,1
# x1,5,2
# x1,5,3
# x1,5,4
# x1,5,5
# x1,5,6
# x1,5,7
# x1,5,8
# y1,6
# x1,6,0
# x1,6,1
# x1,6,2
# x1,6,3
# x1,6,4
# x1,6,5
# x1,6,6
# x1,6,7
# x1,6,8
# y1,7
# x1,7,0
# x1,7,1
# x1,7,2
# x1,7,3
# x1,7,4
# x1,7,5
# x1,7,6
# x1,7,7
# x1,7,8
# y1,8
# x1,8,0
# x1,8,1
# x1,8,2
# x1,8,3
# x1,8,4
# x1,8,5
# x1,8,6
# x1,8,7
# x1,8,8
# yd0,1
# yd0,2
# yd0,3
# yd0,4
# yd0,5
# yd0,6
# yd0,7
# t0,0
# t0,1
# t0,2
# t0,3
# t0,4
# t0,5
# t0,6
# t0,7
# t0,8
# t1,0
# t1,1
# t1,2
# t1,3
# t1,4
# t1,5
# t1,6
# t1,7
# t1,8
# td0,0
# td0,1
# td0,2
# td0,3
# td0,4
# td0,5
# td0,6
# td0,7
# td0,8
# u0
# u1
# u2
# u3
# u4
# u5
# u6
# u7
# u8
# u0
# u1
# u2
# u3
# u4
# u5
# u6
# u7
# u8
# QDV
# 166.09099985222034
# traveltime
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 391 rows, 315 columns and 1508 nonzeros
# Model fingerprint: 0x3d194aa0
# Model has 1 quadratic constraint
# Variable types: 128 continuous, 187 integer (187 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+09]
#   QMatrix range    [1e+00, 3e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 139 rows and 155 columns
# Presolve time: 0.01s
# Presolved: 286 rows, 211 columns, 1755 nonzeros
# Presolved model has 34 SOS constraint(s)
# Variable types: 67 continuous, 144 integer (144 binary)
# Found heuristic solution: objective 454.3109708
#
# Root relaxation: objective 2.104800e+00, 106 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.10480    0   45  454.31097    2.10480   100%     -    0s
# H    0     0                     390.8119588    2.10480  99.5%     -    0s
# H    0     0                     373.4233160    2.10480  99.4%     -    0s
#      0     0   32.58446    0   45  373.42332   32.58446  91.3%     -    0s
# H    0     0                     373.4233069   32.58446  91.3%     -    0s
# H    0     0                     373.4232716   32.58446  91.3%     -    0s
#      0     0   32.69537    0   45  373.42327   32.69537  91.2%     -    0s
#      0     0   33.08701    0   45  373.42327   33.08701  91.1%     -    0s
# H    0     0                     337.9623322   33.08701  90.2%     -    0s
#      0     0   33.11837    0   45  337.96233   33.11837  90.2%     -    0s
#      0     0   33.25180    0   45  337.96233   33.25180  90.2%     -    0s
#      0     0   33.25180    0   45  337.96233   33.25180  90.2%     -    0s
#      0     2   33.25180    0   45  337.96233   33.25180  90.2%     -    0s
# H   35    44                     299.4931173   60.79707  79.7%  39.2    0s
# *   86    94              13     198.4568508   64.12423  67.7%  27.2    0s
# *  183    91               8     173.9781396   67.26094  61.3%  21.3    0s
# *  224    73               9     162.0016897   67.26094  58.5%  20.4    0s
#
# Cutting planes:
#   Learned: 3
#   Implied bound: 41
#   MIR: 4
#   RLT: 2
#   Relax-and-lift: 35
#
# Explored 336 nodes (6795 simplex iterations) in 0.17 seconds (0.11 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 162.002 173.978 198.457 ... 454.311
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.620016896848e+02, best bound 1.620016896848e+02, gap 0.0000%
# w10,0
# w10,1
# w10,2
# w10,3
# w10,4
# w10,5
# w10,6
# w10,7
# w10,8
# w11,0
# w11,1
# w11,2
# w11,3
# w11,4
# w11,5
# w11,6
# w11,7
# w11,8
# w20,0
# w20,1
# w20,2
# w20,3
# w20,4
# w20,5
# w20,6
# w20,7
# w20,8
# w30,0
# w30,1
# w30,2
# w30,3
# w30,4
# w30,5
# w30,6
# w30,7
# w30,8
# w31,0
# w31,1
# w31,2
# w31,3
# w31,4
# w31,5
# w31,6
# w31,7
# w31,8
# w40,0
# w40,1
# w40,2
# w40,3
# w40,4
# w40,5
# w40,6
# w40,7
# w40,8
# w50,0
# w50,1
# w50,2
# w50,3
# w50,4
# w50,5
# w50,6
# w50,7
# w50,8
# w51,0
# w51,1
# w51,2
# w51,3
# w51,4
# w51,5
# w51,6
# w51,7
# w51,8
# w60,0
# w60,1
# w60,2
# w60,3
# w60,4
# w60,5
# w60,6
# w60,7
# w60,8
# y0,0
# x0,0,0
# x0,0,1
# x0,0,2
# x0,0,3
# x0,0,4
# x0,0,5
# x0,0,6
# x0,0,7
# x0,0,8
# y0,1
# x0,1,0
# x0,1,1
# x0,1,2
# x0,1,3
# x0,1,4
# x0,1,5
# x0,1,6
# x0,1,7
# x0,1,8
# y0,2
# x0,2,0
# x0,2,1
# x0,2,2
# x0,2,3
# x0,2,4
# x0,2,5
# x0,2,6
# x0,2,7
# x0,2,8
# y0,3
# x0,3,0
# x0,3,1
# x0,3,2
# x0,3,3
# x0,3,4
# x0,3,5
# x0,3,6
# x0,3,7
# x0,3,8
# y0,4
# x0,4,0
# x0,4,1
# x0,4,2
# x0,4,3
# x0,4,4
# x0,4,5
# x0,4,6
# x0,4,7
# x0,4,8
# y0,5
# x0,5,0
# x0,5,1
# x0,5,2
# x0,5,3
# x0,5,4
# x0,5,5
# x0,5,6
# x0,5,7
# x0,5,8
# y0,6
# x0,6,0
# x0,6,1
# x0,6,2
# x0,6,3
# x0,6,4
# x0,6,5
# x0,6,6
# x0,6,7
# x0,6,8
# y0,7
# x0,7,0
# x0,7,1
# x0,7,2
# x0,7,3
# x0,7,4
# x0,7,5
# x0,7,6
# x0,7,7
# x0,7,8
# y0,8
# x0,8,0
# x0,8,1
# x0,8,2
# x0,8,3
# x0,8,4
# x0,8,5
# x0,8,6
# x0,8,7
# x0,8,8
# y1,0
# x1,0,0
# x1,0,1
# x1,0,2
# x1,0,3
# x1,0,4
# x1,0,5
# x1,0,6
# x1,0,7
# x1,0,8
# y1,1
# x1,1,0
# x1,1,1
# x1,1,2
# x1,1,3
# x1,1,4
# x1,1,5
# x1,1,6
# x1,1,7
# x1,1,8
# y1,2
# x1,2,0
# x1,2,1
# x1,2,2
# x1,2,3
# x1,2,4
# x1,2,5
# x1,2,6
# x1,2,7
# x1,2,8
# y1,3
# x1,3,0
# x1,3,1
# x1,3,2
# x1,3,3
# x1,3,4
# x1,3,5
# x1,3,6
# x1,3,7
# x1,3,8
# y1,4
# x1,4,0
# x1,4,1
# x1,4,2
# x1,4,3
# x1,4,4
# x1,4,5
# x1,4,6
# x1,4,7
# x1,4,8
# y1,5
# x1,5,0
# x1,5,1
# x1,5,2
# x1,5,3
# x1,5,4
# x1,5,5
# x1,5,6
# x1,5,7
# x1,5,8
# y1,6
# x1,6,0
# x1,6,1
# x1,6,2
# x1,6,3
# x1,6,4
# x1,6,5
# x1,6,6
# x1,6,7
# x1,6,8
# y1,7
# x1,7,0
# x1,7,1
# x1,7,2
# x1,7,3
# x1,7,4
# x1,7,5
# x1,7,6
# x1,7,7
# x1,7,8
# y1,8
# x1,8,0
# x1,8,1
# x1,8,2
# x1,8,3
# x1,8,4
# x1,8,5
# x1,8,6
# x1,8,7
# x1,8,8
# yd0,1
# yd0,2
# yd0,3
# yd0,4
# yd0,5
# yd0,6
# yd0,7
# t0,0
# t0,1
# t0,2
# t0,3
# t0,4
# t0,5
# t0,6
# t0,7
# t0,8
# t1,0
# t1,1
# t1,2
# t1,3
# t1,4
# t1,5
# t1,6
# t1,7
# t1,8
# td0,0
# td0,1
# td0,2
# td0,3
# td0,4
# td0,5
# td0,6
# td0,7
# td0,8
# u0
# u1
# u2
# u3
# u4
# u5
# u6
# u7
# u8
# u0
# u1
# u2
# u3
# u4
# u5
# u6
# u7
# u8
# QDV
# 162.8169996774198
# traveltime
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 391 rows, 315 columns and 1508 nonzeros
# Model fingerprint: 0x84e77ad4
# Model has 1 quadratic constraint
# Variable types: 128 continuous, 187 integer (187 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+09]
#   QMatrix range    [1e+00, 3e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [4e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 139 rows and 155 columns
# Presolve time: 0.01s
# Presolved: 286 rows, 211 columns, 1755 nonzeros
# Presolved model has 34 SOS constraint(s)
# Variable types: 67 continuous, 144 integer (144 binary)
# Found heuristic solution: objective 451.0009612
#
# Root relaxation: objective 2.806400e+00, 106 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.80640    0   45  451.00096    2.80640  99.4%     -    0s
# H    0     0                     388.2546215    2.80640  99.3%     -    0s
# H    0     0                     370.9984379    2.80640  99.2%     -    0s
# H    0     0                     370.9984274    3.30120  99.1%     -    0s
#      0     0    3.40480    0   45  370.99843    3.40480  99.1%     -    0s
# H    0     0                     370.9983906    3.40480  99.1%     -    0s
#      0     0   27.83915    0   45  370.99839   27.83915  92.5%     -    0s
#      0     0   33.73181    0   45  370.99839   33.73181  90.9%     -    0s
#      0     0   33.76801    0   45  370.99839   33.76801  90.9%     -    0s
#      0     0   33.92681    0   45  370.99839   33.92681  90.9%     -    0s
#      0     0   33.92681    0   45  370.99839   33.92681  90.9%     -    0s
#      0     2   33.92681    0   45  370.99839   33.92681  90.9%     -    0s
# H   22    26                     363.4535472   57.07487  84.3%  54.4    0s
# H   31    44                     363.4535031   61.63576  83.0%  46.8    0s
# H   33    44                     301.8709747   61.63576  79.6%  45.1    0s
# H   40    44                     295.5102178   66.22682  77.6%  42.0    0s
# *   65    66               8     244.8572809   66.22682  73.0%  33.1    0s
# *  109   116              14     242.8781580   66.22682  72.7%  26.0    0s
# *  132   121              14     231.9990401   66.22682  71.5%  23.5    0s
#
# Cutting planes:
#   Learned: 3
#   Cover: 1
#   Implied bound: 35
#   Clique: 4
#   MIR: 8
#   RLT: 2
#   Relax-and-lift: 36
#
# Explored 278 nodes (3987 simplex iterations) in 0.14 seconds (0.10 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 231.999 242.878 244.857 ... 388.255
# No other solutions better than 231.999
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (4.4944e-06) exceeds tolerance
# Best objective 2.319990361195e+02, best bound 2.319990361195e+02, gap 0.0000%
# w10,0
# w10,1
# w10,2
# w10,3
# w10,4
# w10,5
# w10,6
# w10,7
# w10,8
# w11,0
# w11,1
# w11,2
# w11,3
# w11,4
# w11,5
# w11,6
# w11,7
# w11,8
# w20,0
# w20,1
# w20,2
# w20,3
# w20,4
# w20,5
# w20,6
# w20,7
# w20,8
# w30,0
# w30,1
# w30,2
# w30,3
# w30,4
# w30,5
# w30,6
# w30,7
# w30,8
# w31,0
# w31,1
# w31,2
# w31,3
# w31,4
# w31,5
# w31,6
# w31,7
# w31,8
# w40,0
# w40,1
# w40,2
# w40,3
# w40,4
# w40,5
# w40,6
# w40,7
# w40,8
# w50,0
# w50,1
# w50,2
# w50,3
# w50,4
# w50,5
# w50,6
# w50,7
# w50,8
# w51,0
# w51,1
# w51,2
# w51,3
# w51,4
# w51,5
# w51,6
# w51,7
# w51,8
# w60,0
# w60,1
# w60,2
# w60,3
# w60,4
# w60,5
# w60,6
# w60,7
# w60,8
# y0,0
# x0,0,0
# x0,0,1
# x0,0,2
# x0,0,3
# x0,0,4
# x0,0,5
# x0,0,6
# x0,0,7
# x0,0,8
# y0,1
# x0,1,0
# x0,1,1
# x0,1,2
# x0,1,3
# x0,1,4
# x0,1,5
# x0,1,6
# x0,1,7
# x0,1,8
# y0,2
# x0,2,0
# x0,2,1
# x0,2,2
# x0,2,3
# x0,2,4
# x0,2,5
# x0,2,6
# x0,2,7
# x0,2,8
# y0,3
# x0,3,0
# x0,3,1
# x0,3,2
# x0,3,3
# x0,3,4
# x0,3,5
# x0,3,6
# x0,3,7
# x0,3,8
# y0,4
# x0,4,0
# x0,4,1
# x0,4,2
# x0,4,3
# x0,4,4
# x0,4,5
# x0,4,6
# x0,4,7
# x0,4,8
# y0,5
# x0,5,0
# x0,5,1
# x0,5,2
# x0,5,3
# x0,5,4
# x0,5,5
# x0,5,6
# x0,5,7
# x0,5,8
# y0,6
# x0,6,0
# x0,6,1
# x0,6,2
# x0,6,3
# x0,6,4
# x0,6,5
# x0,6,6
# x0,6,7
# x0,6,8
# y0,7
# x0,7,0
# x0,7,1
# x0,7,2
# x0,7,3
# x0,7,4
# x0,7,5
# x0,7,6
# x0,7,7
# x0,7,8
# y0,8
# x0,8,0
# x0,8,1
# x0,8,2
# x0,8,3
# x0,8,4
# x0,8,5
# x0,8,6
# x0,8,7
# x0,8,8
# y1,0
# x1,0,0
# x1,0,1
# x1,0,2
# x1,0,3
# x1,0,4
# x1,0,5
# x1,0,6
# x1,0,7
# x1,0,8
# y1,1
# x1,1,0
# x1,1,1
# x1,1,2
# x1,1,3
# x1,1,4
# x1,1,5
# x1,1,6
# x1,1,7
# x1,1,8
# y1,2
# x1,2,0
# x1,2,1
# x1,2,2
# x1,2,3
# x1,2,4
# x1,2,5
# x1,2,6
# x1,2,7
# x1,2,8
# y1,3
# x1,3,0
# x1,3,1
# x1,3,2
# x1,3,3
# x1,3,4
# x1,3,5
# x1,3,6
# x1,3,7
# x1,3,8
# y1,4
# x1,4,0
# x1,4,1
# x1,4,2
# x1,4,3
# x1,4,4
# x1,4,5
# x1,4,6
# x1,4,7
# x1,4,8
# y1,5
# x1,5,0
# x1,5,1
# x1,5,2
# x1,5,3
# x1,5,4
# x1,5,5
# x1,5,6
# x1,5,7
# x1,5,8
# y1,6
# x1,6,0
# x1,6,1
# x1,6,2
# x1,6,3
# x1,6,4
# x1,6,5
# x1,6,6
# x1,6,7
# x1,6,8
# y1,7
# x1,7,0
# x1,7,1
# x1,7,2
# x1,7,3
# x1,7,4
# x1,7,5
# x1,7,6
# x1,7,7
# x1,7,8
# y1,8
# x1,8,0
# x1,8,1
# x1,8,2
# x1,8,3
# x1,8,4
# x1,8,5
# x1,8,6
# x1,8,7
# x1,8,8
# yd0,1
# yd0,2
# yd0,3
# yd0,4
# yd0,5
# yd0,6
# yd0,7
# t0,0
# t0,1
# t0,2
# t0,3
# t0,4
# t0,5
# t0,6
# t0,7
# t0,8
# t1,0
# t1,1
# t1,2
# t1,3
# t1,4
# t1,5
# t1,6
# t1,7
# t1,8
# td0,0
# td0,1
# td0,2
# td0,3
# td0,4
# td0,5
# td0,6
# td0,7
# td0,8
# u0
# u1
# u2
# u3
# u4
# u5
# u6
# u7
# u8
# u0
# u1
# u2
# u3
# u4
# u5
# u6
# u7
# u8
# QDV
# 235.06899597187152
# traveltime
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 391 rows, 315 columns and 1508 nonzeros
# Model fingerprint: 0x9ce994fb
# Model has 1 quadratic constraint
# Variable types: 128 continuous, 187 integer (187 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+09]
#   QMatrix range    [1e+00, 3e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [5e-02, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 139 rows and 155 columns
# Presolve time: 0.01s
# Presolved: 286 rows, 211 columns, 1755 nonzeros
# Presolved model has 34 SOS constraint(s)
# Variable types: 67 continuous, 144 integer (144 binary)
# Found heuristic solution: objective 447.6909516
#
# Root relaxation: objective 3.508000e+00, 106 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0
work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 203.418 211.004 332.128 ... 444.381
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (1.6212e-05) exceeds tolerance
# Best objective 2.034183407694e+02, best bound 2.034183403563e+02, gap 0.0000%
# w10,0
# w10,1
# w10,2
# w10,3
# w10,4
# w10,5
# w10,6
# w10,7
# w10,8
# w11,0
# w11,1
# w11,2
# w11,3
# w11,4
# w11,5
# w11,6
# w11,7
# w11,8
# w20,0
# w20,1
# w20,2
# w20,3
# w20,4
# w20,5
# w20,6
# w20,7
# w20,8
# w30,0
# w30,1
# w30,2
# w30,3
# w30,4
# w30,5
# w30,6
# w30,7
# w30,8
# w31,0
# w31,1
# w31,2
# w31,3
# w31,4
# w31,5
# w31,6
# w31,7
# w31,8
# w40,0
# w40,1
# w40,2
# w40,3
# w40,4
# w40,5
# w40,6
# w40,7
# w40,8
# w50,0
# w50,1
# w50,2
# w50,3
# w50,4
# w50,5
# w50,6
# w50,7
# w50,8
# w51,0
# w51,1
# w51,2
# w51,3
# w51,4
# w51,5
# w51,6
# w51,7
# w51,8
# w60,0
# w60,1
# w60,2
# w60,3
# w60,4
# w60,5
# w60,6
# w60,7
# w60,8
# y0,0
# x0,0,0
# x0,0,1
# x0,0,2
# x0,0,3
# x0,0,4
# x0,0,5
# x0,0,6
# x0,0,7
# x0,0,8
# y0,1
# x0,1,0
# x0,1,1
# x0,1,2
# x0,1,3
# x0,1,4
# x0,1,5
# x0,1,6
# x0,1,7
# x0,1,8
# y0,2
# x0,2,0
# x0,2,1
# x0,2,2
# x0,2,3
# x0,2,4
# x0,2,5
# x0,2,6
# x0,2,7
# x0,2,8
# y0,3
# x0,3,0
# x0,3,1
# x0,3,2
# x0,3,3
# x0,3,4
# x0,3,5
# x0,3,6
# x0,3,7
# x0,3,8
# y0,4
# x0,4,0
# x0,4,1
# x0,4,2
# x0,4,3
# x0,4,4
# x0,4,5
# x0,4,6
# x0,4,7
# x0,4,8
# y0,5
# x0,5,0
# x0,5,1
# x0,5,2
# x0,5,3
# x0,5,4
# x0,5,5
# x0,5,6
# x0,5,7
# x0,5,8
# y0,6
# x0,6,0
# x0,6,1
# x0,6,2
# x0,6,3
# x0,6,4
# x0,6,5
# x0,6,6
# x0,6,7
# x0,6,8
# y0,7
# x0,7,0
# x0,7,1
# x0,7,2
# x0,7,3
# x0,7,4
# x0,7,5
# x0,7,6
# x0,7,7
# x0,7,8
# y0,8
# x0,8,0
# x0,8,1
# x0,8,2
# x0,8,3
# x0,8,4
# x0,8,5
# x0,8,6
# x0,8,7
# x0,8,8
# y1,0
# x1,0,0
# x1,0,1
# x1,0,2
# x1,0,3
# x1,0,4
# x1,0,5
# x1,0,6
# x1,0,7
# x1,0,8
# y1,1
# x1,1,0
# x1,1,1
# x1,1,2
# x1,1,3
# x1,1,4
# x1,1,5
# x1,1,6
# x1,1,7
# x1,1,8
# y1,2
# x1,2,0
# x1,2,1
# x1,2,2
# x1,2,3
# x1,2,4
# x1,2,5
# x1,2,6
# x1,2,7
# x1,2,8
# y1,3
# x1,3,0
# x1,3,1
# x1,3,2
# x1,3,3
# x1,3,4
# x1,3,5
# x1,3,6
# x1,3,7
# x1,3,8
# y1,4
# x1,4,0
# x1,4,1
# x1,4,2
# x1,4,3
# x1,4,4
# x1,4,5
# x1,4,6
# x1,4,7
# x1,4,8
# y1,5
# x1,5,0
# x1,5,1
# x1,5,2
# x1,5,3
# x1,5,4
# x1,5,5
# x1,5,6
# x1,5,7
# x1,5,8
# y1,6
# x1,6,0
# x1,6,1
# x1,6,2
# x1,6,3
# x1,6,4
# x1,6,5
# x1,6,6
# x1,6,7
# x1,6,8
# y1,7
# x1,7,0
# x1,7,1
# x1,7,2
# x1,7,3
# x1,7,4
# x1,7,5
# x1,7,6
# x1,7,7
# x1,7,8
# y1,8
# x1,8,0
# x1,8,1
# x1,8,2
# x1,8,3
# x1,8,4
# x1,8,5
# x1,8,6
# x1,8,7
# x1,8,8
# yd0,1
# yd0,2
# yd0,3
# yd0,4
# yd0,5
# yd0,6
# yd0,7
# t0,0
# t0,1
# t0,2
# t0,3
# t0,4
# t0,5
# t0,6
# t0,7
# t0,8
# t1,0
# t1,1
# t1,2
# t1,3
# t1,4
# t1,5
# t1,6
# t1,7
# t1,8
# td0,0
# td0,1
# td0,2
# td0,3
# td0,4
# td0,5
# td0,6
# td0,7
# td0,8
# u0
# u1
# u2
# u3
# u4
# u5
# u6
# u7
# u8
# u0
# u1
# u2
# u3
# u4
# u5
# u6
# u7
# u8
# QDV
# 208.23100079751546
# traveltime
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 391 rows, 315 columns and 1508 nonzeros
# Model fingerprint: 0x8d5a8030
# Model has 1 quadratic constraint
# Variable types: 128 continuous, 187 integer (187 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+09]
#   QMatrix range    [1e+00, 3e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [7e-02, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 139 rows and 155 columns
# Presolve time: 0.01s
# Presolved: 286 rows, 211 columns, 1755 nonzeros
# Presolved model has 34 SOS constraint(s)
# Variable types: 67 continuous, 144 integer (144 binary)
# Found heuristic solution: objective 441.0709324
#
# Root relaxation: objective 4.911200e+00, 106 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.91120    0   45  441.07093    4.91120  98.9%     -    0s
# H    0     0                     380.5825996    4.91120  98.7%     -    0s
# H    0     0                     363.7238016    4.91120  98.6%     -    0s
# H    0     0                     333.9533415   29.18251  91.3%     -    0s
#      0     0   34.96617    0   45  333.95334   34.96617  89.5%     -    0s
# H    0     0                     333.9532909   34.96617  89.5%     -    0s
#      0     0   35.14232    0   45  333.95329   35.14232  89.5%     -    0s
#      0     0   35.96277    0   45  333.95329   35.96277  89.2%     -    0s
#      0     0   35.97867    0   45  333.95329   35.97867  89.2%     -    0s
#      0     0   36.31429    0   45  333.95329   36.31429  89.1%     -    0s
#      0     0   36.31429    0   45  333.95329   36.31429  89.1%     -    0s
#      0     2   36.31429    0   45  333.95329   36.31429  89.1%     -    0s
# H   22    26                     257.1374493   60.74377  76.4%  50.0    0s
# *   67    75               9     171.9576592   67.54635  60.7%  30.5    0s
# *  164    59               7     163.9636299   76.44164  53.4%  24.7    0s
# *  252    19              11     160.9146097   91.93874  42.9%  22.3    0s
#
# Cutting planes:
#   Learned: 3
#   Cover: 2
#   Implied bound: 42
#   MIR: 7
#   RLT: 1
#   Relax-and-lift: 35
#
# Explored 302 nodes (6700 simplex iterations) in 0.15 seconds (0.13 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 160.915 163.964 171.958 ... 441.071
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.609146097432e+02, best bound 1.609146097082e+02, gap 0.0000%
# w10,0
# w10,1
# w10,2
# w10,3
# w10,4
# w10,5
# w10,6
# w10,7
# w10,8
# w11,0
# w11,1
# w11,2
# w11,3
# w11,4
# w11,5
# w11,6
# w11,7
# w11,8
# w20,0
# w20,1
# w20,2
# w20,3
# w20,4
# w20,5
# w20,6
# w20,7
# w20,8
# w30,0
# w30,1
# w30,2
# w30,3
# w30,4
# w30,5
# w30,6
# w30,7
# w30,8
# w31,0
# w31,1
# w31,2
# w31,3
# w31,4
# w31,5
# w31,6
# w31,7
# w31,8
# w40,0
# w40,1
# w40,2
# w40,3
# w40,4
# w40,5
# w40,6
# w40,7
# w40,8
# w50,0
# w50,1
# w50,2
# w50,3
# w50,4
# w50,5
# w50,6
# w50,7
# w50,8
# w51,0
# w51,1
# w51,2
# w51,3
# w51,4
# w51,5
# w51,6
# w51,7
# w51,8
# w60,0
# w60,1
# w60,2
# w60,3
# w60,4
# w60,5
# w60,6
# w60,7
# w60,8
# y0,0
# x0,0,0
# x0,0,1
# x0,0,2
# x0,0,3
# x0,0,4
# x0,0,5
# x0,0,6
# x0,0,7
# x0,0,8
# y0,1
# x0,1,0
# x0,1,1
# x0,1,2
# x0,1,3
# x0,1,4
# x0,1,5
# x0,1,6
# x0,1,7
# x0,1,8
# y0,2
# x0,2,0
# x0,2,1
# x0,2,2
# x0,2,3
# x0,2,4
# x0,2,5
# x0,2,6
# x0,2,7
# x0,2,8
# y0,3
# x0,3,0
# x0,3,1
# x0,3,2
# x0,3,3
# x0,3,4
# x0,3,5
# x0,3,6
# x0,3,7
# x0,3,8
# y0,4
# x0,4,0
# x0,4,1
# x0,4,2
# x0,4,3
# x0,4,4
# x0,4,5
# x0,4,6
# x0,4,7
# x0,4,8
# y0,5
# x0,5,0
# x0,5,1
# x0,5,2
# x0,5,3
# x0,5,4
# x0,5,5
# x0,5,6
# x0,5,7
# x0,5,8
# y0,6
# x0,6,0
# x0,6,1
# x0,6,2
# x0,6,3
# x0,6,4
# x0,6,5
# x0,6,6
# x0,6,7
# x0,6,8
# y0,7
# x0,7,0
# x0,7,1
# x0,7,2
# x0,7,3
# x0,7,4
# x0,7,5
# x0,7,6
# x0,7,7
# x0,7,8
# y0,8
# x0,8,0
# x0,8,1
# x0,8,2
# x0,8,3
# x0,8,4
# x0,8,5
# x0,8,6
# x0,8,7
# x0,8,8
# y1,0
# x1,0,0
# x1,0,1
# x1,0,2
# x1,0,3
# x1,0,4
# x1,0,5
# x1,0,6
# x1,0,7
# x1,0,8
# y1,1
# x1,1,0
# x1,1,1
# x1,1,2
# x1,1,3
# x1,1,4
# x1,1,5
# x1,1,6
# x1,1,7
# x1,1,8
# y1,2
# x1,2,0
# x1,2,1
# x1,2,2
# x1,2,3
# x1,2,4
# x1,2,5
# x1,2,6
# x1,2,7
# x1,2,8
# y1,3
# x1,3,0
# x1,3,1
# x1,3,2
# x1,3,3
# x1,3,4
# x1,3,5
# x1,3,6
# x1,3,7
# x1,3,8
# y1,4
# x1,4,0
# x1,4,1
# x1,4,2
# x1,4,3
# x1,4,4
# x1,4,5
# x1,4,6
# x1,4,7
# x1,4,8
# y1,5
# x1,5,0
# x1,5,1
# x1,5,2
# x1,5,3
# x1,5,4
# x1,5,5
# x1,5,6
# x1,5,7
# x1,5,8
# y1,6
# x1,6,0
# x1,6,1
# x1,6,2
# x1,6,3
# x1,6,4
# x1,6,5
# x1,6,6
# x1,6,7
# x1,6,8
# y1,7
# x1,7,0
# x1,7,1
# x1,7,2
# x1,7,3
# x1,7,4
# x1,7,5
# x1,7,6
# x1,7,7
# x1,7,8
# y1,8
# x1,8,0
# x1,8,1
# x1,8,2
# x1,8,3
# x1,8,4
# x1,8,5
# x1,8,6
# x1,8,7
# x1,8,8
# yd0,1
# yd0,2
# yd0,3
# yd0,4
# yd0,5
# yd0,6
# yd0,7
# t0,0
# t0,1
# t0,2
# t0,3
# t0,4
# t0,5
# t0,6
# t0,7
# t0,8
# t1,0
# t1,1
# t1,2
# t1,3
# t1,4
# t1,5
# t1,6
# t1,7
# t1,8
# td0,0
# td0,1
# td0,2
# td0,3
# td0,4
# td0,5
# td0,6
# td0,7
# td0,8
# u0
# u1
# u2
# u3
# u4
# u5
# u6
# u7
# u8
# u0
# u1
# u2
# u3
# u4
# u5
# u6
# u7
# u8
# QDV
# 162.8169997285604
# traveltime
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 391 rows, 315 columns and 1508 nonzeros
# Model fingerprint: 0x9f6e28f7
# Model has 1 quadratic constraint
# Variable types: 128 continuous, 187 integer (187 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+09]
#   QMatrix range    [1e+00, 3e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [8e-02, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 139 rows and 155 columns
# Presolve time: 0.01s
# Presolved: 286 rows, 211 columns, 1755 nonzeros
# Presolved model has 34 SOS constraint(s)
# Variable types: 67 continuous, 144 integer (144 binary)
# Found heuristic solution: objective 437.7609228
#
# Root relaxation: objective 5.612800e+00, 106 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    5.61280    0   45  437.76092    5.61280  98.7%     -    0s
# H    0     0                     378.0252624    5.61280  98.5%     -    0s
# H    0     0                     361.2989202    5.61280  98.4%     -    0s
# H    0     0                     361.2989130    6.60240  98.2%     -    0s
#      0     0    6.80960    0   45  361.29891    6.80960  98.1%     -    0s
# H    0     0                     361.2988705    6.80960  98.1%     -    0s
#      0     0   29.63030    0   45  361.29887   29.63030  91.8%     -    0s
#      0     0   36.71245    0   45  361.29887   36.71245  89.8%     -    0s
#      0     0   36.72493    0   45  361.29887   36.72493  89.8%     -    0s
#      0     0   37.10318    0   45  361.29887   37.10318  89.7%     -    0s
#      0     0   37.11119    0   45  361.29887   37.11119  89.7%     -    0s
#      0     2   37.11119    0   45  361.29887   37.11119  89.7%     -    0s
# H   41    44                     318.6972265   70.02116  78.0%  42.2    0s
# *   70    84               9     236.8011979   79.40498  66.5%  31.4    0s
# *  109   111              14     225.2167973   79.40498  64.7%  25.7    0s
# *  137   113              14     209.3698009   79.40498  62.1%  23.0    0s
0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 4
#   Cover: 12
#   Implied bound: 41
#   Clique: 3
#   MIR: 18
#   Flow cover: 1
#   Inf proof: 1
#   RLT: 10
#   Relax-and-lift: 11
#
# Explored 916 nodes (8419 simplex iterations) in 0.23 seconds (0.15 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 130.353 130.699 131.808 ... 139.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.303530203903e+02, best bound 1.303530201345e+02, gap 0.0000%
# w10,0
# w10,1
# w10,2
# w10,3
# w10,4
# w10,5
# w10,6
# w10,7
# w10,8
# w11,0
# w11,1
# w11,2
# w11,3
# w11,4
# w11,5
# w11,6
# w11,7
# w11,8
# w20,0
# w20,1
# w20,2
# w20,3
# w20,4
# w20,5
# w20,6
# w20,7
# w20,8
# w30,0
# w30,1
# w30,2
# w30,3
# w30,4
# w30,5
# w30,6
# w30,7
# w30,8
# w31,0
# w31,1
# w31,2
# w31,3
# w31,4
# w31,5
# w31,6
# w31,7
# w31,8
# w40,0
# w40,1
# w40,2
# w40,3
# w40,4
# w40,5
# w40,6
# w40,7
# w40,8
# w50,0
# w50,1
# w50,2
# w50,3
# w50,4
# w50,5
# w50,6
# w50,7
# w50,8
# w51,0
# w51,1
# w51,2
# w51,3
# w51,4
# w51,5
# w51,6
# w51,7
# w51,8
# w60,0
# w60,1
# w60,2
# w60,3
# w60,4
# w60,5
# w60,6
# w60,7
# w60,8
# y0,0
# x0,0,0
# x0,0,1
# x0,0,2
# x0,0,3
# x0,0,4
# x0,0,5
# x0,0,6
# x0,0,7
# x0,0,8
# y0,1
# x0,1,0
# x0,1,1
# x0,1,2
# x0,1,3
# x0,1,4
# x0,1,5
# x0,1,6
# x0,1,7
# x0,1,8
# y0,2
# x0,2,0
# x0,2,1
# x0,2,2
# x0,2,3
# x0,2,4
# x0,2,5
# x0,2,6
# x0,2,7
# x0,2,8
# y0,3
# x0,3,0
# x0,3,1
# x0,3,2
# x0,3,3
# x0,3,4
# x0,3,5
# x0,3,6
# x0,3,7
# x0,3,8
# y0,4
# x0,4,0
# x0,4,1
# x0,4,2
# x0,4,3
# x0,4,4
# x0,4,5
# x0,4,6
# x0,4,7
# x0,4,8
# y0,5
# x0,5,0
# x0,5,1
# x0,5,2
# x0,5,3
# x0,5,4
# x0,5,5
# x0,5,6
# x0,5,7
# x0,5,8
# y0,6
# x0,6,0
# x0,6,1
# x0,6,2
# x0,6,3
# x0,6,4
# x0,6,5
# x0,6,6
# x0,6,7
# x0,6,8
# y0,7
# x0,7,0
# x0,7,1
# x0,7,2
# x0,7,3
# x0,7,4
# x0,7,5
# x0,7,6
# x0,7,7
# x0,7,8
# y0,8
# x0,8,0
# x0,8,1
# x0,8,2
# x0,8,3
# x0,8,4
# x0,8,5
# x0,8,6
# x0,8,7
# x0,8,8
# y1,0
# x1,0,0
# x1,0,1
# x1,0,2
# x1,0,3
# x1,0,4
# x1,0,5
# x1,0,6
# x1,0,7
# x1,0,8
# y1,1
# x1,1,0
# x1,1,1
# x1,1,2
# x1,1,3
# x1,1,4
# x1,1,5
# x1,1,6
# x1,1,7
# x1,1,8
# y1,2
# x1,2,0
# x1,2,1
# x1,2,2
# x1,2,3
# x1,2,4
# x1,2,5
# x1,2,6
# x1,2,7
# x1,2,8
# y1,3
# x1,3,0
# x1,3,1
# x1,3,2
# x1,3,3
# x1,3,4
# x1,3,5
# x1,3,6
# x1,3,7
# x1,3,8
# y1,4
# x1,4,0
# x1,4,1
# x1,4,2
# x1,4,3
# x1,4,4
# x1,4,5
# x1,4,6
# x1,4,7
# x1,4,8
# y1,5
# x1,5,0
# x1,5,1
# x1,5,2
# x1,5,3
# x1,5,4
# x1,5,5
# x1,5,6
# x1,5,7
# x1,5,8
# y1,6
# x1,6,0
# x1,6,1
# x1,6,2
# x1,6,3
# x1,6,4
# x1,6,5
# x1,6,6
# x1,6,7
# x1,6,8
# y1,7
# x1,7,0
# x1,7,1
# x1,7,2
# x1,7,3
# x1,7,4
# x1,7,5
# x1,7,6
# x1,7,7
# x1,7,8
# y1,8
# x1,8,0
# x1,8,1
# x1,8,2
# x1,8,3
# x1,8,4
# x1,8,5
# x1,8,6
# x1,8,7
# x1,8,8
# yd0,1
# yd0,2
# yd0,3
# yd0,4
# yd0,5
# yd0,6
# yd0,7
# t0,0
# t0,1
# t0,2
# t0,3
# t0,4
# t0,5
# t0,6
# t0,7
# t0,8
# t1,0
# t1,1
# t1,2
# t1,3
# t1,4
# t1,5
# t1,6
# t1,7
# t1,8
# td0,0
# td0,1
# td0,2
# td0,3
# td0,4
# td0,5
# td0,6
# td0,7
# td0,8
# u0
# u1
# u2
# u3
# u4
# u5
# u6
# u7
# u8
# u0
# u1
# u2
# u3
# u4
# u5
# u6
# u7
# u8
# QDV
# 244.67099939759711
# traveltime
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 391 rows, 315 columns and 1508 nonzeros
# Model fingerprint: 0xf317a7f2
# Model has 1 quadratic constraint
# Variable types: 128 continuous, 187 integer (187 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+09]
#   QMatrix range    [1e+00, 3e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 139 rows and 155 columns
# Presolve time: 0.01s
# Presolved: 286 rows, 211 columns, 1755 nonzeros
# Presolved model has 34 SOS constraint(s)
# Variable types: 67 continuous, 144 integer (144 binary)
# Found heuristic solution: objective 136.5500494
#
# Root relaxation: objective 6.945840e+01, 106 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   69.45840    0   45  136.55005   69.45840  49.1%     -    0s
# H    0     0                     136.5500100   69.45840  49.1%     -    0s
# H    0     0                     129.9140397   82.04230  36.8%     -    0s
#      0     0   82.04230    0   55  129.91404   82.04230  36.8%     -    0s
#      0     0   82.83377    0   71  129.91404   82.83377  36.2%     -    0s
#      0     0   84.86365    0   74  129.91404   84.86365  34.7%     -    0s
#      0     0   89.64103    0   56  129.91404   89.64103  31.0%     -    0s
#      0     0   90.00437    0   58  129.91404   90.00437  30.7%     -    0s
#      0     0   90.04442    0   76  129.91404   90.04442  30.7%     -    0s
#      0     0   90.75201    0   76  129.91404   90.75201  30.1%     -    0s
#      0     0   93.99456    0   52  129.91404   93.99456  27.6%     -    0s
#      0     0   93.99456    0   52  129.91404   93.99456  27.6%     -    0s
#      0     2   93.99456    0   52  129.91404   93.99456  27.6%     -    0s
# *   81    34               7     129.4083601   93.99456  27.4%  13.9    0s
# *  456    75              15     128.6313502  102.07926  20.6%  11.4    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 4
#   Cover: 6
#   Implied bound: 49
#   Clique: 3
#   MIR: 13
#   Flow cover: 1
#   RLT: 13
#   Relax-and-lift: 5
#
# Explored 717 nodes (7594 simplex iterations) in 0.22 seconds (0.14 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 128.631 129.408 129.914 ... 136.55
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.286313502217e+02, best bound 1.286313501720e+02, gap 0.0000%
# w10,0
# w10,1
# w10,2
# w10,3
# w10,4
# w10,5
# w10,6
# w10,7
# w10,8
# w11,0
# w11,1
# w11,2
# w11,3
# w11,4
# w11,5
# w11,6
# w11,7
# w11,8
# w20,0
# w20,1
# w20,2
# w20,3
# w20,4
# w20,5
# w20,6
# w20,7
# w20,8
# w30,0
# w30,1
# w30,2
# w30,3
# w30,4
# w30,5
# w30,6
# w30,7
# w30,8
# w31,0
# w31,1
# w31,2
# w31,3
# w31,4
# w31,5
# w31,6
# w31,7
# w31,8
# w40,0
# w40,1
# w40,2
# w40,3
# w40,4
# w40,5
# w40,6
# w40,7
# w40,8
# w50,0
# w50,1
# w50,2
# w50,3
# w50,4
# w50,5
# w50,6
# w50,7
# w50,8
# w51,0
# w51,1
# w51,2
# w51,3
# w51,4
# w51,5
# w51,6
# w51,7
# w51,8
# w60,0
# w60,1
# w60,2
# w60,3
# w60,4
# w60,5
# w60,6
# w60,7
# w60,8
# y0,0
# x0,0,0
# x0,0,1
# x0,0,2
# x0,0,3
# x0,0,4
# x0,0,5
# x0,0,6
# x0,0,7
# x0,0,8
# y0,1
# x0,1,0
# x0,1,1
# x0,1,2
# x0,1,3
# x0,1,4
# x0,1,5
# x0,1,6
# x0,1,7
# x0,1,8
# y0,2
# x0,2,0
# x0,2,1
# x0,2,2
# x0,2,3
# x0,2,4
# x0,2,5
# x0,2,6
# x0,2,7
# x0,2,8
# y0,3
# x0,3,0
# x0,3,1
# x0,3,2
# x0,3,3
# x0,3,4
# x0,3,5
# x0,3,6
# x0,3,7
# x0,3,8
# y0,4
# x0,4,0
# x0,4,1
# x0,4,2
# x0,4,3
# x0,4,4
# x0,4,5
# x0,4,6
# x0,4,7
# x0,4,8
# y0,5
# x0,5,0
# x0,5,1
# x0,5,2
# x0,5,3
# x0,5,4
# x0,5,5
# x0,5,6
# x0,5,7
# x0,5,8
# y0,6
# x0,6,0
# x0,6,1
# x0,6,2
# x0,6,3
# x0,6,4
# x0,6,5
# x0,6,6
# x0,6,7
# x0,6,8
# y0,7
# x0,7,0
# x0,7,1
# x0,7,2
# x0,7,3
# x0,7,4
# x0,7,5
# x0,7,6
# x0,7,7
# x0,7,8
# y0,8
# x0,8,0
# x0,8,1
# x0,8,2
# x0,8,3
# x0,8,4
# x0,8,5
# x0,8,6
# x0,8,7
# x0,8,8
# y1,0
# x1,0,0
# x1,0,1
# x1,0,2
# x1,0,3
# x1,0,4
# x1,0,5
# x1,0,6
# x1,0,7
# x1,0,8
# y1,1
# x1,1,0
# x1,1,1
# x1,1,2
# x1,1,3
# x1,1,4
# x1,1,5
# x1,1,6
# x1,1,7
# x1,1,8
# y1,2
# x1,2,0
# x1,2,1
# x1,2,2
# x1,2,3
# x1,2,4
# x1,2,5
# x1,2,6
# x1,2,7
# x1,2,8
# y1,3
# x1,3,0
# x1,3,1
# x1,3,2
# x1,3,3
# x1,3,4
# x1,3,5
# x1,3,6
# x1,3,7
# x1,3,8
# y1,4
# x1,4,0
# x1,4,1
# x1,4,2
# x1,4,3
# x1,4,4
# x1,4,5
# x1,4,6
# x1,4,7
# x1,4,8
# y1,5
# x1,5,0
# x1,5,1
# x1,5,2
# x1,5,3
# x1,5,4
# x1,5,5
# x1,5,6
# x1,5,7
# x1,5,8
# y1,6
# x1,6,0
# x1,6,1
# x1,6,2
# x1,6,3
# x1,6,4
# x1,6,5
# x1,6,6
# x1,6,7
# x1,6,8
# y1,7
# x1,7,0
# x1,7,1
# x1,7,2
# x1,7,3
# x1,7,4
# x1,7,5
# x1,7,6
# x1,7,7
# x1,7,8
# y1,8
# x1,8,0
# x1,8,1
# x1,8,2
# x1,8,3
# x1,8,4
# x1,8,5
# x1,8,6
# x1,8,7
# x1,8,8
# yd0,1
# yd0,2
# yd0,3
# yd0,4
# yd0,5
# yd0,6
# yd0,7
# t0,0
# t0,1
# t0,2
# t0,3
# t0,4
# t0,5
# t0,6
# t0,7
# t0,8
# t1,0
# t1,1
# t1,2
# t1,3
# t1,4
# t1,5
# t1,6
# t1,7
# t1,8
# td0,0
# td0,1
# td0,2
# td0,3
# td0,4
# td0,5
# td0,6
# td0,7
# td0,8
# u0
# u1
# u2
# u3
# u4
# u5
# u6
# u7
# u8
# u0
# u1
# u2
# u3
# u4
# u5
# u6
# u7
# u8
# QDV
# 189.15498049047338
# traveltime

# %%
x
x = np.arange(0.0, 1.01, 0.01)
for i in range(len(x)):
    print(x[i])

# %%
model.printAttr('x')

# %%
dt.X[0]

# %%
truck_tours = [[] for k in K]


for k in K:
    truck_tours[k] = [(i,j) for i in C_0 for j in C_plus if x[k,i,j].x > 0.99 ]
plt.plot(dt.X[0], dt.Y[0], c='r', marker='s')

for i in range(1, dt.num_of_customer):
    plt.scatter(dt.X[i], dt.Y[i], c='b')
    plt.annotate(str("  ") + str(int(i)), (dt.X[i], dt.Y[i]))
    
for k in K:
    for i, j in truck_tours[k]:
        if j != dt.num_of_customer:
            plt.plot([dt.X[i], dt.X[j]], [dt.Y[i], dt.Y[j]], c='g', zorder=0)
        else:
            for k, h in truck_tours[k]:
                if h == i:
                    plt.plot([dt.X[i], dt.X[0]], [dt.Y[i], dt.Y[0]], c='g', zorder=0)


                    
for d in D:
    default_width= 1
    for i in C:
        if yd[d,i].x > 0.99:
            plt.plot([dt.X[0],dt.X[i]], [dt.Y[0], dt.Y[i]], color='black', linestyle='dashed', linewidth = default_width)
    



plt.savefig('2.png')

# %%
QDV

# %%
td

# %%
alpha

# %%
yd

# %%
td

# %%
y2 = [200.87, 216.132, 225.17, 198.29, 203.74, 218.134, 199.649, 386.529, 209.481, 252.216, 644.611]
y1 = [141, 163.81, 160.93, 140.93, 152.34, 140.93, 148.85, 142.61, 140.93, 140.93, 139]
x = np.arange(0.0, 1.1, 0.1)
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(x, y1,'o', color='green')
ax2.plot(x, y2, 'o')

ax1.set_xlabel('theta')
ax1.set_ylabel('cost', color='g')
ax2.set_ylabel('QDV', color='b')

# %%
plt.plot([141, 163.81, 160.93, 140.93, 152.34, 140.93, 148.85, 142.61, 140.93, 140.93, 139],'g*', [200.87, 216.132, 225.17, 198.29, 203.74, 218.134, 199.649, 386.529, 209.481, 252.216, 644.611], 'bo')
plt.show()
